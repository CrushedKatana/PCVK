# %% [markdown]
# <a href="https://colab.research.google.com/github/CrushedKatana/PCVK/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as pit

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls= ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
       "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
       "https://i.pinimg.com/736x/1a/84/35/1a8435b262f70dc441a52bf15a9c620d.jpg"]
#baca dan tampilkan image
#loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                                 #read image
  image = cv.resize (image, (0,0), fx = 0.5, fy = 0.5 )  #resize image to half size
  image_2 =  cv.cvtColor(image, cv.COLOR_BGR2RGB)        #convert color to RGB
  final_frame = cv.hconcat((image, image_2))             #concatenate image
  cv2_imshow(final_frame)                                #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=736x368>

# %%
tinggi = image_2.shape[0]
lebar= image_2.shape[1]
print("resolusi image: tinggi x lebar ",tinggi," x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar  368  x  368
# <PIL.Image.Image image mode=RGB size=368x368>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x368>

# %% [markdown]
# Question
# 1. Explain why in this practicum module the execution of Python code is done using Google Colab?
#
# 2. Explain the use of each library in the eighth step practicum? Do all these libraries have to be used in this practical session?
#
# 3. In the 8th step of the experiment there is a snippet of program code as follows: image cv.resize(image, (0,0), fx = 0.5 fy = 8.5 )
# What is the use of the program code? and what is the effect if it is not done?
#
# 4. Take a look at the following program code snippet:
#
# membuat garis horizontal ditengah image
# for y in range (lebar): image_3[int((tinggi)/2),y) = [255,255,255]
# What is the use of the code [255,255,255] ? Explain!
#
# 5. Explain the relationship between pixels and high or low image resolution!
#
# Answer
# 1. Colab = zero setup (browser-only), same environment for everyone, free GPU/TPU, easy sharing, Drive/files baked in, reproducible notebooks.
#
# 2. Likely libs in step 8:
#
#   cv2 (OpenCV): read/show/resize, draw/edit pixels.
#
#   numpy: image as arrays, indexing, math.
#
#   matplotlib: visualize images inline.
#
# 3. cv.resize(image, (0,0), fx=0.5, fy=8.5) scales the image: width ×0.5, height ×8.5 (non-uniform, changes aspect ratio). If you skip it, the image stays original size; later steps expecting a certain size/aspect might not work or be slower. Note: there should be a comma between fx and fy.
#
# 4. [255,255,255] sets the pixel color to white (in OpenCV that’s B=255, G=255, R=255). That line paints a white horizontal line across the middle row.
#
# 5. Pixels are the smallest samples; resolution = how many pixels (e.g., 1920×1080). More pixels → more detail. Perceived sharpness also depends on pixel density (PPI): same pixel count on a larger display looks less sharp.
